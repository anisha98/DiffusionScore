# %%
# !unzip /content/adjMatrix.zip

# %%
import math
import queue
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
## Function to find all the adjacent nodes to each node in the network
def adjacency_matrix(visited,stack,stack_alpha): 
    g = data
    rows = g.shape[0]
    cols = g.shape[1]
    for x in range(0, rows):
        l = []
        for y in range(0, cols):
            if(g[x,y] == 1):
                l.append(y)
        adj.append(l)
    #print(adj)

# %%
# Function to define the parent nodes of the current node
def parent_create(d, parent):
  for j in d:
      parent[j] = []
      for i in range(len(adj)):
          if j in adj[i]:
            parent[j].append(i)
#parent

# %%
## Depth First Search function is used to find the distance of each node from each other in the network
def DFS(v,visited,stack,stack_alpha):
    visited[v] = 1
    stack.append(v)
    for i in adj[v]:
        if visited[i] == 0:
            stack_alpha[i] = stack_alpha[v] + 1.0 # if there is a link between two nodes then the distance is incremented
            DFS(i,visited,stack,stack_alpha)
    #print("Stack_alpha",stack_alpha)
    return stack_alpha

# %%
## Depth First Search function is used to combine all the values of closeness centrality and degree centrality and value of
## stack_alpha which is the value of the parent node of the current node
def Depth(v,visited,stack,stack_alpha):
    visited[v] = 1
    stack.append(v)
    #print("Visited",v)
    #print("Stack",stack)
    for i in adj[v]:
        #print("Current",i)
        if visited[i] == 0:
            stack_alpha[i] = (stack_alpha[v]) - d[i,0]/N + c[i,0]/N
            Depth(i,visited,stack,stack_alpha)
    #print("Stack_alpha",stack_alpha)
    return stack_alpha

# %%
def heat_layer(y):
    return sum(heat[y])

# %%
df1 = pd.DataFrame(columns = ['Article_ID','Snip','Score','Heat_values','Layers','Hops','Direct_citation','Indirect_citation','Total_Nodes'])

# %%
data_snip = pd.read_csv('/content/initial_heats.csv')
snip = data_snip['bIDs'].tolist()
data_snip.head()
#snip
# Out:
#    Unnamed: 0  bIDs  heat
# 0           0     0    10
# 1           1     1    10
# 2           2     3    10
# 3           3     4    10
# 4           4     5    10

# %%
data_snip[['bIDs']].min()
# Out:
# bIDs    0
# dtype: int64

# %%
# Step number 1) Read the data from each university and for each adjacency matrix
directory = 'adj_mat/'
names = ['']
#names = ['clemenson/','colorado/','missouri/','nevada/','new mexico/','north dakota/','oregon/','south carolina/','stony brook/','temple/','vermont/','west virginia/']
for i1 in names:
    final = os.listdir(directory+i1)
    for i,name in enumerate(final): # Iterate through all the files in directory + names
        print("Name",name)
        if(name == '.ipynb_checkpoints'):
          continue
        num = int(name[:-4]) # Splitting the string to find the article id 
        if num in snip:
            univ = i1 # assign vairbale univerisity for the current university data
            if(directory+i1+name):
                data = pd.read_csv(directory+i1+name) #Read data using Pandas
                idx = data.index[data['Unnamed: 0'] == str(num)] ## Since the location of the source node in the adjacency matrix is not
                ## known we get the index of the source node from the matrix 
                idx.tolist() # convert the index value into a list for later use(this solves the type problem)
                data = data.drop('Unnamed: 0',axis = 1) ## preprocess the data to make it into a numpy array
                data = data.to_numpy()
                N = len(data[0]) ##Total no of nodes in the matrix 
                #print(N)
                #print("source heat",idx[0])
                # Initialise variables 
                visited = [0]*N # used for DFS
                stack = [] # used for DFS
                stack_alpha = [0]*N # used for DFS
                adj = [] # to store the adjacency matrix returned from the adjacency_matrix function 

                # function call to adjacency_matrix
                adjacency_matrix(visited,stack,stack_alpha)

                d1 = [i for i in range(0,N)]
                d1.pop(idx[0])
                parent = {}
                parent_create(d1,parent)
                #print(parent)
                alpha_matrix = [] # to store the distance of each node from one another
                for i in range(N):
                    initial_node = i
                    stack = []
                    stack_alpha = [0.0]*N
                    visited = [0]*N
                    stack_alpha[i] = 1.0
                    p = DFS(i,visited,stack,stack_alpha)
                    alpha_matrix.append(p)
                for i in range(N):
                    for j in range(N):
                        if(alpha_matrix[i][j] > 0.0):
                            alpha_matrix[i][j] -=1 ## decrementing the distance by one to make counting start from 0
                for i in range(N):
                    alpha_matrix[i][i] = 0.0
                #print("Alpha_matrix",alpha_matrix)
                layers = alpha_matrix

                ## for closeness centrality - calculated by summing all the values in the rows of the alpha_matrix
                c = np.zeros(shape=(N,1))
                c = np.zeros(shape=(N,1))
                for i in range(N):
                    sum_dist = 0
                    for j in range(N):
                        if(alpha_matrix[i][j] >0):
                            sum_dist += 1
                    c[i,0] = sum_dist

                #print(c)
                ## Defines the heat kernal
                H = np.zeros(shape=(N,N))
                row = H.shape[0]
                col = H.shape[1]
                d = np.zeros(shape=(N,1)) 
                din = np.zeros(shape=(N,1))
                dout = np.zeros(shape=(N,1))
                g = data
                #count = -10
                for y in range(0,row):
                    p = g[y] == np.array([0]*N)
                    equal = p.all()
                    for x in range(0,col):
                        dout[y,0] -= g[y,x] #outgoing nodes - should ideally distribute the heat to the next nodes
                        din[y,0] += g[x,y] #ingoing nodes - should ideally increase the heat of each node
                    d[y,0] = din[y,0] + dout[y,0]

                ## To avoid having null values in the closeness centrality array we replace the 0s with -1 else negate the values 
                ## for futher calculation purpose
                for i in range(N):
                    if c[i,0]== 0:
                        c[i,0] = 1
                #print(d)
                # to store the distance of each node from one another
                alpha_matrix = []
                for i in range(N):
                    initial_node = i
                    stack = []
                    stack_alpha = [0.0]*N
                    visited = [0]*N
                    stack_alpha[i] = 1.0
                    p = Depth(i,visited,stack,stack_alpha)
                    alpha_matrix.append(p)
                for i in range(N):
                    alpha_matrix[i][i] = -1.0 ## decrementing the distance by one to make counting start from 0

                #print(alpha_matrix)
                g = data
                for x in range(0,N):
                    for y in range(0,N):  
                         if g[y,x] == 1 and alpha_matrix[y][x] != 0:
                            H[x,y] +=1/(alpha_matrix[y][x])#+c[y,0] + d[y,0]#
                         else:
                           H[x,y] -= alpha_matrix[y][x]/N ## this is for all the other node combinations and hence we dont want
                            ## their influence to affect the calculated values much so we divide by N(No of total nodes in the network)

                initial_node = idx[0]
                arr = [0.0]*N
                arr[initial_node] = float(data_snip.loc[data_snip['bIDs'] == num, 'heat'].iloc[0])
                ## to initiate the source node value to be equal to its snip or h-index value
                initial_heat = np.array(arr)
                ## using heat equation calculating the heat in the network where t = 1
                heat = np.dot((np.exp(H)),initial_heat)
                #print("initial array",initial_heat)
                #print("heat initially",heat)
                heat1 = [0.0]*N
                ## normalising the values in the range of 2-1
                for i in range(len(heat)):
                    heat1[i] = ( (heat[i] - heat.min()) / (heat.max() - heat.min()) ) * (2 - 1) + 1

                ## normalising the values in the range of 0-1
                #print(arr[initial_node])
                for i in range(len(heat1)):
                    heat1[i] = (heat1[i]/2.0) * arr[initial_node]

                for i in range(len(heat)):
                    heat[i] = heat1[i]

                #print("after normalisation",heat)
                t = np.array(layers)
                d1 = {} 
                for i in range(N):
                    d1[i] = []

                ## Code after from here onwards is to find the heat layer wise in the network
                def printLevels(graph, V, x): 
                  # array to store level of each node  
                  level = [[] for i in range(N)]
                  # create a queue  
                  stk = []
                  stk.append(x)
                  level[x].append(0)
                  marked = [False for i in range(N)]
                  while(len(stk) != 0):
                      x1 = stk.pop()
                      if marked[x1] == False:
                        for i in graph[x1]:
                            if(i == idx[0]):
                              pass
                            else:
                              stk.append(i)
                              #print(i)
                              o = parent.get(i)
                              for j in o:
                                if(level[j] != []):
                                  for k in level[j]:
                                      level[i].append(k + 1)
                                      level[i] = list(set(level[i]))
                      marked[x1] = True

                  # display all nodes and their levels  
                  #print(level)
                  for i in range(N):
                      #print(level[i])
                      d1[i] = level[i]
  
                # Driver Code  
                if __name__ == '__main__': 
                    
                    # adjacency graph for tree  
                    V = N
                    graph = adj
                    printLevels(graph, V, idx[0]) 
    
                ## contains data of which and all layers each node comes in
                final_dictionary =  d1 
                f_d = {}
                max_val = 0
                ## calculates the total number of hops in the network
                for key,values in final_dictionary.items():
                    f_d[key] = list(set(values))
                    max_i = max(f_d[key])
                    if(max_i > max_val):
                        max_val = max_i

                ## to calculate all the nodes present in each hops ex: hop1:[node1,node23], hop2:[node0,node12] ...
                d_layer = {} 
                for i in range(max_val+1):
                    d_layer[i] = []
                for i in range(max_val+1):
                    for key,values in f_d.items():
                        if i in values:
                            d_layer[i].append(key)

                ##length of first hop is the direct citation
                direct_citation = len(d_layer[1])
                o = d_layer.copy()
                o.pop(0)
                o.pop(1)
                indirect_citation = 0
                ## sum of length of all the other layers except the first one
                for i,values in o.items():
                    indirect_citation += len(values)
                if(indirect_citation > 1):
                    indirect_citation -=1
                tot = N
                avg_heat_layer = []
                d_layer.pop(0) ## this contains the source node we dont want the heat in the source to be there for the calculation
                ## of the heat in each layer

                ## to calculate heat in each layer
                for i in range(1,max_val+1):
                    avg_heat_layer.append(heat_layer(d_layer[i])/len(d_layer[i]))

                ## sum all the heats in each layer
                score = sum(avg_heat_layer)
                #print(num,len(d_layer[1]),d_layer[1],direct_citation,max_val)
                print("We are done entering the value")
                print("*"*100)
                ## append the values to a dataframe for saving purpose
                ##['Article_ID','Snip','Score','Heat_values','Layers','Hops','Direct_citation','Indirect_citation','Total_Nodes']
                df1 = df1.append({ 'Article_ID': num,'Snip':float(data_snip.loc[data_snip['bIDs'] == num, 'heat'].iloc[0]),'Score':score,'Heat_values':heat,'Layers':d_layer,'Hops':float(max_val),'Direct_citation':float(direct_citation),'Indirect_citation':float(indirect_citation),'Total_Nodes':float(tot),'UScore':0.0}, ignore_index=True)
            else:
                continue
# Out:
# Streaming output truncated to the last 5000 lines.
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3611.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '277.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4362.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1538.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4407.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '622.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1308.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '873.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2785.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1217.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2779.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1894.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1986.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4335.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2509.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3184.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '865.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5427.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5089.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3968.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '419.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '483.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2293.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '262.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1255.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4437.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4233.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5002.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '332.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1064.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '902.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2554.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2122.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1679.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1696.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3411.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4167.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4321.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2319.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '681.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5165.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '355.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5397.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '535.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5646.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '43.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4502.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '969.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '304.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4860.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2300.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4105.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '940.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3655.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '984.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5594.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4343.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5368.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5212.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '540.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2537.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4084.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2455.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2837.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '264.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4118.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2549.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2217.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5374.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5545.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4332.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3557.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4298.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1380.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '576.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2119.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2090.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3363.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3415.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1718.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2999.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '903.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '932.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4268.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2970.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2441.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4188.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5170.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '296.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3518.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3008.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5529.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3891.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1741.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2730.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3730.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1579.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '910.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1792.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1369.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '108.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2559.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3907.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2757.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3829.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1136.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4391.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '611.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2166.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3235.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3952.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5001.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '18.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '913.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2101.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3501.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3911.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3768.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2113.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '661.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1030.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2576.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1537.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '456.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3440.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1942.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4525.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4908.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2825.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2289.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '112.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1811.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4450.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1979.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2033.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2816.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3409.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '93.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1799.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2663.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3018.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1852.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '709.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3232.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1772.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '319.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3314.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '498.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1701.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4928.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '708.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1972.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1955.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5605.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '394.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2546.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1351.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5072.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4031.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2032.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1997.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '37.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2539.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5364.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2815.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1107.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3362.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3137.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3468.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1625.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '52.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2326.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1754.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '167.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3830.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3580.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3864.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '161.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1568.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4210.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '154.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5169.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2508.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '466.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5270.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3989.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3901.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '305.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2167.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1220.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5409.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3617.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1864.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '981.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3020.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '785.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4342.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3066.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1608.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1506.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4518.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4005.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3001.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2352.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3013.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1505.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3711.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5247.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4983.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3609.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1477.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1544.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '435.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2803.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5288.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2060.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2911.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3696.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5205.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4426.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3214.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3087.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2589.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4072.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2968.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2743.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1511.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5464.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1755.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5000.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2548.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1077.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3217.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5067.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3396.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5141.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1417.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1407.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5506.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4591.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '634.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1188.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '217.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3966.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3263.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3367.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4396.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2241.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3936.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2331.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3653.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2876.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1146.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3683.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5471.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '566.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4325.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '749.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1714.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3639.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '640.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '590.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4439.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1335.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1322.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4099.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3762.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5431.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4996.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5016.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4513.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '908.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5455.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4374.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '610.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3086.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '58.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '132.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3447.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '346.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1365.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4365.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2394.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3284.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3573.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2806.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2601.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1999.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4166.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '391.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1803.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4200.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1260.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '860.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3223.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1436.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2871.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3492.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1024.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3473.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1989.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4935.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5329.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1250.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2777.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3854.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '255.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5624.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1943.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5549.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1737.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '325.csv')
# We are done entering the value
# ...
# ****************************************************************************************************
# ('Name', '137.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4911.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4413.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5513.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4527.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3822.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3526.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1355.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1403.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1744.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4468.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1431.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3413.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2661.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '721.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1490.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2597.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4102.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '533.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1207.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '125.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2935.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3153.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '962.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '427.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '437.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2145.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5143.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3866.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '115.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2874.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1012.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '889.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4956.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3488.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2345.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1672.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2341.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '455.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3662.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2452.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3179.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5282.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1075.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '186.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2325.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2680.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '168.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1212.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4862.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '504.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2693.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '487.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4655.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '442.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5299.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1466.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3574.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1850.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '357.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2862.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '833.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2753.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1356.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5677.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3838.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3621.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1486.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1121.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2144.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2560.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '597.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '827.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5078.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1411.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2540.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2443.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4863.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '569.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2490.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3670.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5091.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '716.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4680.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4566.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1584.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3340.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1707.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '4465.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '263.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '181.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2169.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1415.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '2666.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1766.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1826.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5133.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1607.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3870.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '3019.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '5348.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '1615.csv')
# We are done entering the value
# ****************************************************************************************************
# ('Name', '334.csv')
# We are done entering the value
# ****************************************************************************************************

# %%
len(df1)
# Out:
# 3696

# %%
df1.to_csv("NEW VALUES.csv")
